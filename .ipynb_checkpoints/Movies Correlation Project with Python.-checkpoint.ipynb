# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import zipfile
plt.style.use('ggplot')
from matplotlib.pyplot import figure
matplotlib.rcParams['figure.figsize'] = (12, 8)

# %%
# Read the data 
df = pd.read_csv('movies.csv')

# %%
df = df.reindex(columns=['name', 'genre', 'budget', 'gross','company','country', 'runtime', 'director', 'writer', 'star',  'rating', 'year', 'released', 'score', 'votes'])

# %%
# lets look at the data 
df.head()
# Out:
#                                              name      genre      budget  \
# 0                                     The Shining      Drama  19000000.0
# 1                                 The Blue Lagoon  Adventure   4500000.0
# 2  Star Wars: Episode V - The Empire Strikes Back     Action  18000000.0
# 3                                       Airplane!     Comedy   3500000.0
# 4                                      Caddyshack     Comedy   6000000.0
#
#          gross             company         country  runtime         director  \
# 0   46998772.0        Warner Bros.  United Kingdom    146.0  Stanley Kubrick
# 1   58853106.0   Columbia Pictures   United States    104.0   Randal Kleiser
# 2  538375067.0           Lucasfilm   United States    124.0   Irvin Kershner
# 3   83453539.0  Paramount Pictures   United States     88.0     Jim Abrahams
# 4   39846344.0      Orion Pictures   United States     98.0     Harold Ramis
#
#                     writer            star rating  year  \
# 0             Stephen King  Jack Nicholson      R  1980
# 1  Henry De Vere Stacpoole  Brooke Shields      R  1980
# 2           Leigh Brackett     Mark Hamill     PG  1980
# 3             Jim Abrahams     Robert Hays     PG  1980
# 4       Brian Doyle-Murray     Chevy Chase      R  1980
#
#                         released  score      votes
# 0  June 13, 1980 (United States)    8.4   927000.0
# 1   July 2, 1980 (United States)    5.8    65000.0
# 2  June 20, 1980 (United States)    8.7  1200000.0
# 3   July 2, 1980 (United States)    7.7   221000.0
# 4  July 25, 1980 (United States)    7.3   108000.0

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} {:2f}%'.format(col, pct_missing))
# Out:
# name 0.000000%
# genre 0.000000%
# budget 0.283125%
# gross 0.024648%
# company 0.002217%
# country 0.000391%
# runtime 0.000522%
# director 0.000000%
# writer 0.000391%
# star 0.000130%
# rating 0.010042%
# year 0.000000%
# released 0.000261%
# score 0.000391%
# votes 0.000391%

# %%
# check fo rnull values
df.isnull().sum()
# Out:
# name           0
# genre          0
# budget      2171
# gross        189
# company       17
# country        3
# runtime        4
# director       0
# writer         3
# star           1
# rating        77
# year           0
# released       2
# score          3
# votes          3
# dtype: int64

# %%
# lets drop null values
df.dropna(inplace=True)

# %%
# check the number of columns and rows
df.shape
# Out:
# (5421, 15)

# %%
# Check data types
df.dtypes
# Out:
# name         object
# genre        object
# budget      float64
# gross       float64
# company      object
# country      object
# runtime     float64
# director     object
# writer       object
# star         object
# rating       object
# year          int64
# released     object
# score       float64
# votes       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5421 non-null   object
#  1   genre     5421 non-null   object
#  2   budget    5421 non-null   float64
#  3   gross     5421 non-null   float64
#  4   company   5421 non-null   object
#  5   country   5421 non-null   object
#  6   runtime   5421 non-null   float64
#  7   director  5421 non-null   object
#  8   writer    5421 non-null   object
#  9   star      5421 non-null   object
#  10  rating    5421 non-null   object
#  11  year      5421 non-null   int64
#  12  released  5421 non-null   object
#  13  score     5421 non-null   float64
#  14  votes     5421 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 677.6+ KB

# %%
 #change data type to int 
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#                                              name      genre    budget  \
# 0                                     The Shining      Drama  19000000
# 1                                 The Blue Lagoon  Adventure   4500000
# 2  Star Wars: Episode V - The Empire Strikes Back     Action  18000000
# 3                                       Airplane!     Comedy   3500000
# 4                                      Caddyshack     Comedy   6000000
#
#        gross             company         country  runtime         director  \
# 0   46998772        Warner Bros.  United Kingdom    146.0  Stanley Kubrick
# 1   58853106   Columbia Pictures   United States    104.0   Randal Kleiser
# 2  538375067           Lucasfilm   United States    124.0   Irvin Kershner
# 3   83453539  Paramount Pictures   United States     88.0     Jim Abrahams
# 4   39846344      Orion Pictures   United States     98.0     Harold Ramis
#
#                     writer            star rating  year  \
# 0             Stephen King  Jack Nicholson      R  1980
# 1  Henry De Vere Stacpoole  Brooke Shields      R  1980
# 2           Leigh Brackett     Mark Hamill     PG  1980
# 3             Jim Abrahams     Robert Hays     PG  1980
# 4       Brian Doyle-Murray     Chevy Chase      R  1980
#
#                         released  score      votes
# 0  June 13, 1980 (United States)    8.4   927000.0
# 1   July 2, 1980 (United States)    5.8    65000.0
# 2  June 20, 1980 (United States)    8.7  1200000.0
# 3   July 2, 1980 (United States)    7.7   221000.0
# 4  July 25, 1980 (United States)    7.3   108000.0

# %%
# lets get year from released date
df['yearcorrect'] =  df['released'].astype(str).str.split(',').str[1].str[:5]

# %%
df.head()
# Out:
#                                              name      genre    budget  \
# 0                                     The Shining      Drama  19000000
# 1                                 The Blue Lagoon  Adventure   4500000
# 2  Star Wars: Episode V - The Empire Strikes Back     Action  18000000
# 3                                       Airplane!     Comedy   3500000
# 4                                      Caddyshack     Comedy   6000000
#
#        gross             company         country  runtime         director  \
# 0   46998772        Warner Bros.  United Kingdom    146.0  Stanley Kubrick
# 1   58853106   Columbia Pictures   United States    104.0   Randal Kleiser
# 2  538375067           Lucasfilm   United States    124.0   Irvin Kershner
# 3   83453539  Paramount Pictures   United States     88.0     Jim Abrahams
# 4   39846344      Orion Pictures   United States     98.0     Harold Ramis
#
#                     writer            star rating  year  \
# 0             Stephen King  Jack Nicholson      R  1980
# 1  Henry De Vere Stacpoole  Brooke Shields      R  1980
# 2           Leigh Brackett     Mark Hamill     PG  1980
# 3             Jim Abrahams     Robert Hays     PG  1980
# 4       Brian Doyle-Murray     Chevy Chase      R  1980
#
#                         released  score      votes yearcorrect
# 0  June 13, 1980 (United States)    8.4   927000.0        1980
# 1   July 2, 1980 (United States)    5.8    65000.0        1980
# 2  June 20, 1980 (United States)    8.7  1200000.0        1980
# 3   July 2, 1980 (United States)    7.7   221000.0        1980
# 4  July 25, 1980 (United States)    7.3   108000.0        1980

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name   genre     budget  \
# 5445                                      Avatar  Action  237000000
# 7445                           Avengers: Endgame  Action  356000000
# 3045                                     Titanic   Drama  200000000
# 6663  Star Wars: Episode VII - The Force Awakens  Action  245000000
# 7244                      Avengers: Infinity War  Action  321000000
# ...                                          ...     ...        ...
# 5640                                 Tanner Hall   Drama    3000000
# 2434                  Philadelphia Experiment II  Action    5000000
# 3681                                Ginger Snaps   Drama    5000000
# 272                                     Parasite  Horror     800000
# 3203                                  Trojan War  Comedy   15000000
#
#            gross                    company        country  runtime  \
# 5445  2847246203      Twentieth Century Fox  United States    162.0
# 7445  2797501328             Marvel Studios  United States    181.0
# 3045  2201647264      Twentieth Century Fox  United States    194.0
# 6663  2069521700                  Lucasfilm  United States    138.0
# 7244  2048359754             Marvel Studios  United States    149.0
# ...          ...                        ...            ...      ...
# 5640        5073           Two Prong Lesson  United States     96.0
# 2434        2970           Trimark Pictures  United States     97.0
# 3681        2554  Copperheart Entertainment         Canada    108.0
# 272         2270           Embassy Pictures  United States     85.0
# 3203         309                   Daybreak  United States     85.0
#
#                  director                   writer               star  \
# 5445        James Cameron            James Cameron    Sam Worthington
# 7445        Anthony Russo       Christopher Markus  Robert Downey Jr.
# 3045        James Cameron            James Cameron  Leonardo DiCaprio
# 6663          J.J. Abrams          Lawrence Kasdan       Daisy Ridley
# 7244        Anthony Russo       Christopher Markus  Robert Downey Jr.
# ...                   ...                      ...                ...
# 5640  Francesca Gregorini  Tatiana von Fürstenberg        Rooney Mara
# 2434     Stephen Cornwell       Wallace C. Bennett       Brad Johnson
# 3681         John Fawcett             Karen Walton      Emily Perkins
# 272          Charles Band            Alan J. Adler    Robert Glaudini
# 3203         George Huang                Andy Burg       Will Friedle
#
#          rating  year                           released  score      votes  \
# 5445      PG-13  2009  December 18, 2009 (United States)    7.8  1100000.0
# 7445      PG-13  2019     April 26, 2019 (United States)    8.4   903000.0
# 3045      PG-13  1997  December 19, 1997 (United States)    7.8  1100000.0
# 6663      PG-13  2015  December 18, 2015 (United States)    7.8   876000.0
# 7244      PG-13  2018     April 27, 2018 (United States)    8.4   897000.0
# ...         ...   ...                                ...    ...        ...
# 5640          R  2009          January 15, 2015 (Sweden)    5.8     3500.0
# 2434      PG-13  1993         June 4, 1994 (South Korea)    4.5     1900.0
# 3681  Not Rated  2000              May 11, 2001 (Canada)    6.8    43000.0
# 272           R  1982     March 12, 1982 (United States)    3.9     2300.0
# 3203      PG-13  1997           October 1, 1997 (Brazil)    5.7     5800.0
#
#      yearcorrect
# 5445        2009
# 7445        2019
# 3045        1997
# 6663        2015
# 7244        2018
# ...          ...
# 5640        2015
# 2434        1994
# 3681        2001
# 272         1982
# 3203        1997
#
# [5421 rows x 16 columns]

# %%
# check and drop duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check data
df
# Out:
#                                                 name      genre       budget  \
# 0                                        The Shining      Drama   19000000.0
# 1                                    The Blue Lagoon  Adventure    4500000.0
# 2     Star Wars: Episode V - The Empire Strikes Back     Action   18000000.0
# 3                                          Airplane!     Comedy    3500000.0
# 4                                         Caddyshack     Comedy    6000000.0
# ...                                              ...        ...          ...
# 7648                               Bad Boys for Life     Action   90000000.0
# 7649                              Sonic the Hedgehog     Action   85000000.0
# 7650                                        Dolittle  Adventure  175000000.0
# 7651                            The Call of the Wild  Adventure  135000000.0
# 7652                               The Eight Hundred     Action   80000000.0
#
#             gross                              company         country  \
# 0      46998772.0                         Warner Bros.  United Kingdom
# 1      58853106.0                    Columbia Pictures   United States
# 2     538375067.0                            Lucasfilm   United States
# 3      83453539.0                   Paramount Pictures   United States
# 4      39846344.0                       Orion Pictures   United States
# ...           ...                                  ...             ...
# 7648  426505244.0                    Columbia Pictures   United States
# 7649  319715683.0                   Paramount Pictures   United States
# 7650  245487753.0                   Universal Pictures   United States
# 7651  111105497.0                 20th Century Studios          Canada
# 7652  461421559.0  Beijing Diqi Yinxiang Entertainment           China
#
#       runtime         director                   writer               star  \
# 0       146.0  Stanley Kubrick             Stephen King     Jack Nicholson
# 1       104.0   Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2       124.0   Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        88.0     Jim Abrahams             Jim Abrahams        Robert Hays
# 4        98.0     Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...       ...              ...                      ...                ...
# 7648    124.0     Adil El Arbi              Peter Craig         Will Smith
# 7649     99.0      Jeff Fowler                Pat Casey       Ben Schwartz
# 7650    101.0   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 7651    100.0    Chris Sanders            Michael Green      Harrison Ford
# 7652    149.0          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#          rating  year                           released  score      votes
# 0             R  1980      June 13, 1980 (United States)    8.4   927000.0
# 1             R  1980       July 2, 1980 (United States)    5.8    65000.0
# 2            PG  1980      June 20, 1980 (United States)    8.7  1200000.0
# 3            PG  1980       July 2, 1980 (United States)    7.7   221000.0
# 4             R  1980      July 25, 1980 (United States)    7.3   108000.0
# ...         ...   ...                                ...    ...        ...
# 7648          R  2020   January 17, 2020 (United States)    6.6   140000.0
# 7649         PG  2020  February 14, 2020 (United States)    6.5   102000.0
# 7650         PG  2020   January 17, 2020 (United States)    5.6    53000.0
# 7651         PG  2020  February 21, 2020 (United States)    6.8    42000.0
# 7652  Not Rated  2020    August 28, 2020 (United States)    6.8     3700.0
#
# [5421 rows x 15 columns]

# %%
# lets build a scatter plot with budget and gross
plt.scatter(x=df['budget'],  y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
df.sort_values(by='gross', ascending=False)
# Out:
#                                             name   genre     budget  \
# 5445                                      Avatar  Action  237000000
# 7445                           Avengers: Endgame  Action  356000000
# 3045                                     Titanic   Drama  200000000
# 6663  Star Wars: Episode VII - The Force Awakens  Action  245000000
# 7244                      Avengers: Infinity War  Action  321000000
# ...                                          ...     ...        ...
# 5640                                 Tanner Hall   Drama    3000000
# 2434                  Philadelphia Experiment II  Action    5000000
# 3681                                Ginger Snaps   Drama    5000000
# 272                                     Parasite  Horror     800000
# 3203                                  Trojan War  Comedy   15000000
#
#            gross                    company        country  runtime  \
# 5445  2847246203      Twentieth Century Fox  United States    162.0
# 7445  2797501328             Marvel Studios  United States    181.0
# 3045  2201647264      Twentieth Century Fox  United States    194.0
# 6663  2069521700                  Lucasfilm  United States    138.0
# 7244  2048359754             Marvel Studios  United States    149.0
# ...          ...                        ...            ...      ...
# 5640        5073           Two Prong Lesson  United States     96.0
# 2434        2970           Trimark Pictures  United States     97.0
# 3681        2554  Copperheart Entertainment         Canada    108.0
# 272         2270           Embassy Pictures  United States     85.0
# 3203         309                   Daybreak  United States     85.0
#
#                  director                   writer               star  \
# 5445        James Cameron            James Cameron    Sam Worthington
# 7445        Anthony Russo       Christopher Markus  Robert Downey Jr.
# 3045        James Cameron            James Cameron  Leonardo DiCaprio
# 6663          J.J. Abrams          Lawrence Kasdan       Daisy Ridley
# 7244        Anthony Russo       Christopher Markus  Robert Downey Jr.
# ...                   ...                      ...                ...
# 5640  Francesca Gregorini  Tatiana von Fürstenberg        Rooney Mara
# 2434     Stephen Cornwell       Wallace C. Bennett       Brad Johnson
# 3681         John Fawcett             Karen Walton      Emily Perkins
# 272          Charles Band            Alan J. Adler    Robert Glaudini
# 3203         George Huang                Andy Burg       Will Friedle
#
#          rating  year                           released  score      votes  \
# 5445      PG-13  2009  December 18, 2009 (United States)    7.8  1100000.0
# 7445      PG-13  2019     April 26, 2019 (United States)    8.4   903000.0
# 3045      PG-13  1997  December 19, 1997 (United States)    7.8  1100000.0
# 6663      PG-13  2015  December 18, 2015 (United States)    7.8   876000.0
# 7244      PG-13  2018     April 27, 2018 (United States)    8.4   897000.0
# ...         ...   ...                                ...    ...        ...
# 5640          R  2009          January 15, 2015 (Sweden)    5.8     3500.0
# 2434      PG-13  1993         June 4, 1994 (South Korea)    4.5     1900.0
# 3681  Not Rated  2000              May 11, 2001 (Canada)    6.8    43000.0
# 272           R  1982     March 12, 1982 (United States)    3.9     2300.0
# 3203      PG-13  1997           October 1, 1997 (Brazil)    5.7     5800.0
#
#      yearcorrect
# 5445        2009
# 7445        2019
# 3045        1997
# 6663        2015
# 7244        2018
# ...          ...
# 5640        2015
# 2434        1994
# 3681        2001
# 272         1982
# 3203        1997
#
# [5421 rows x 16 columns]

# %%
# plot a regplot for see corelation
sns.regplot(data=df, x='budget', y='gross', scatter_kws={'color': 'red'}, line_kws={'color': 'blue'});

# %%
# lets start looking at correlation  between columns

# %%
#by default the coor() uses the pearson's correlation
df.corr(method='pearson')
# Out:
#            budget     gross   runtime      year     score     votes
# budget   1.000000  0.740247  0.318695  0.327722  0.072001  0.439675
# gross    0.740247  1.000000  0.275796  0.274321  0.222556  0.614751
# runtime  0.318695  0.275796  1.000000  0.075077  0.414068  0.352303
# year     0.327722  0.274321  0.075077  1.000000  0.056386  0.206021
# score    0.072001  0.222556  0.414068  0.056386  1.000000  0.474256
# votes    0.439675  0.614751  0.352303  0.206021  0.474256  1.000000

# %% [markdown]
# There is a high corelation between

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matric for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show();

# %%
df_categorized = df
for col in df_categorized.columns:
    if (df_categorized[col].dtype == 'object'):
        df_categorized[col] = df_categorized[col].astype('category')
        df_categorized[col] = df_categorized[col].cat.codes
        
df_categorized
# Out:
#       name  genre     budget      gross  company  country  runtime  director  \
# 0     4692      6   19000000   46998772     1426       46    146.0      1795
# 1     3929      1    4500000   58853106      452       47    104.0      1578
# 2     3641      0   18000000  538375067      945       47    124.0       757
# 3      204      4    3500000   83453539     1108       47     88.0       889
# 4      732      4    6000000   39846344     1083       47     98.0       719
# ...    ...    ...        ...        ...      ...      ...      ...       ...
# 7648   415      0   90000000  426505244      452       47    124.0        16
# 7649  3556      0   85000000  319715683     1108       47     99.0       852
# 7650  1153      1  175000000  245487753     1397       47    101.0      1809
# 7651  3978      1  135000000  111105497       12        6    100.0       294
# 7652  4090      0   80000000  461421559      228        8    149.0       746
#
#       writer  star  rating  year  released  score      votes  yearcorrect
# 0       2832   699       6  1980      1304    8.4   927000.0            0
# 1       1158   214       6  1980      1127    5.8    65000.0            0
# 2       1818  1157       4  1980      1359    8.7  1200000.0            0
# 3       1413  1474       4  1980      1127    7.7   221000.0            0
# 4        351   271       6  1980      1170    7.3   108000.0            0
# ...      ...   ...     ...   ...       ...    ...        ...          ...
# 7648    2390  1812       6  2020       904    6.6   140000.0           40
# 7649    2309   147       4  2020       713    6.5   102000.0           40
# 7650    2827  1470       4  2020       904    5.6    53000.0           40
# 7651    2091   640       4  2020       758    6.8    42000.0           40
# 7652    1184  1839       3  2020       370    6.8     3700.0           40
#
# [5421 rows x 16 columns]

# %%
df
# Out:
#                                                 name      genre       budget  \
# 0                                        The Shining      Drama   19000000.0
# 1                                    The Blue Lagoon  Adventure    4500000.0
# 2     Star Wars: Episode V - The Empire Strikes Back     Action   18000000.0
# 3                                          Airplane!     Comedy    3500000.0
# 4                                         Caddyshack     Comedy    6000000.0
# ...                                              ...        ...          ...
# 7648                               Bad Boys for Life     Action   90000000.0
# 7649                              Sonic the Hedgehog     Action   85000000.0
# 7650                                        Dolittle  Adventure  175000000.0
# 7651                            The Call of the Wild  Adventure  135000000.0
# 7652                               The Eight Hundred     Action   80000000.0
#
#             gross                              company         country  \
# 0      46998772.0                         Warner Bros.  United Kingdom
# 1      58853106.0                    Columbia Pictures   United States
# 2     538375067.0                            Lucasfilm   United States
# 3      83453539.0                   Paramount Pictures   United States
# 4      39846344.0                       Orion Pictures   United States
# ...           ...                                  ...             ...
# 7648  426505244.0                    Columbia Pictures   United States
# 7649  319715683.0                   Paramount Pictures   United States
# 7650  245487753.0                   Universal Pictures   United States
# 7651  111105497.0                 20th Century Studios          Canada
# 7652  461421559.0  Beijing Diqi Yinxiang Entertainment           China
#
#       runtime         director                   writer               star  \
# 0       146.0  Stanley Kubrick             Stephen King     Jack Nicholson
# 1       104.0   Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2       124.0   Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        88.0     Jim Abrahams             Jim Abrahams        Robert Hays
# 4        98.0     Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...       ...              ...                      ...                ...
# 7648    124.0     Adil El Arbi              Peter Craig         Will Smith
# 7649     99.0      Jeff Fowler                Pat Casey       Ben Schwartz
# 7650    101.0   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 7651    100.0    Chris Sanders            Michael Green      Harrison Ford
# 7652    149.0          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#          rating  year                           released  score      votes
# 0             R  1980      June 13, 1980 (United States)    8.4   927000.0
# 1             R  1980       July 2, 1980 (United States)    5.8    65000.0
# 2            PG  1980      June 20, 1980 (United States)    8.7  1200000.0
# 3            PG  1980       July 2, 1980 (United States)    7.7   221000.0
# 4             R  1980      July 25, 1980 (United States)    7.3   108000.0
# ...         ...   ...                                ...    ...        ...
# 7648          R  2020   January 17, 2020 (United States)    6.6   140000.0
# 7649         PG  2020  February 14, 2020 (United States)    6.5   102000.0
# 7650         PG  2020   January 17, 2020 (United States)    5.6    53000.0
# 7651         PG  2020  February 21, 2020 (United States)    6.8    42000.0
# 7652  Not Rated  2020    August 28, 2020 (United States)    6.8     3700.0
#
# [5421 rows x 15 columns]

# %%
correlation_matrix = df_categorized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matric for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.figure(figsize=(15, 15))
plt.show();

# %%
df_categorized.corr()
# Out:
#                  name     genre    budget     gross   company   country  \
# name         1.000000  0.010996  0.023392  0.005639  0.021697 -0.025490
# genre        0.010996  1.000000 -0.368523 -0.244101 -0.071334 -0.009164
# budget       0.023392 -0.368523  1.000000  0.740247  0.170235  0.052977
# gross        0.005639 -0.244101  0.740247  1.000000  0.149553  0.060078
# company      0.021697 -0.071334  0.170235  0.149553  1.000000  0.048569
# country     -0.025490 -0.009164  0.052977  0.060078  0.048569  1.000000
# runtime      0.010850 -0.059237  0.318695  0.275796  0.037585 -0.034477
# director     0.015246 -0.008553 -0.009662 -0.029560 -0.008223  0.011133
# writer       0.012880  0.017578 -0.039466 -0.035885 -0.003697  0.022488
# star        -0.006882  0.003341 -0.021473 -0.000004  0.014082 -0.009990
# rating      -0.029234  0.147796 -0.203946 -0.181906 -0.092357  0.008230
# year         0.025542 -0.073167  0.327722  0.274321 -0.014333 -0.066748
# released    -0.006152  0.022142  0.019952  0.008501 -0.002407 -0.017228
# score        0.014450  0.035106  0.072001  0.222556  0.020656 -0.043051
# votes        0.012615 -0.135990  0.439675  0.614751  0.118470  0.041551
# yearcorrect  0.026759 -0.070699  0.321624  0.269479 -0.015587 -0.072407
#
#               runtime  director    writer      star    rating      year  \
# name         0.010850  0.015246  0.012880 -0.006882 -0.029234  0.025542
# genre       -0.059237 -0.008553  0.017578  0.003341  0.147796 -0.073167
# budget       0.318695 -0.009662 -0.039466 -0.021473 -0.203946  0.327722
# gross        0.275796 -0.029560 -0.035885 -0.000004 -0.181906  0.274321
# company      0.037585 -0.008223 -0.003697  0.014082 -0.092357 -0.014333
# country     -0.034477  0.011133  0.022488 -0.009990  0.008230 -0.066748
# runtime      1.000000  0.017433 -0.017561  0.010108  0.140792  0.075077
# director     0.017433  1.000000  0.261735  0.036593  0.014656 -0.038354
# writer      -0.017561  0.261735  1.000000  0.018520 -0.003149 -0.025908
# star         0.010108  0.036593  0.018520  1.000000  0.009196 -0.032157
# rating       0.140792  0.014656 -0.003149  0.009196  1.000000  0.019499
# year         0.075077 -0.038354 -0.025908 -0.032157  0.019499  1.000000
# released     0.008975  0.002308  0.008072  0.015706  0.018083 -0.001740
# score        0.414068  0.005413  0.012843  0.007296  0.065983  0.056386
# votes        0.352303 -0.010376 -0.005316 -0.017638  0.006031  0.206021
# yearcorrect  0.076666 -0.035738 -0.023603 -0.030840  0.019560  0.996723
#
#              released     score     votes  yearcorrect
# name        -0.006152  0.014450  0.012615     0.026759
# genre        0.022142  0.035106 -0.135990    -0.070699
# budget       0.019952  0.072001  0.439675     0.321624
# gross        0.008501  0.222556  0.614751     0.269479
# company     -0.002407  0.020656  0.118470    -0.015587
# country     -0.017228 -0.043051  0.041551    -0.072407
# runtime      0.008975  0.414068  0.352303     0.076666
# director     0.002308  0.005413 -0.010376    -0.035738
# writer       0.008072  0.012843 -0.005316    -0.023603
# star         0.015706  0.007296 -0.017638    -0.030840
# rating       0.018083  0.065983  0.006031     0.019560
# year        -0.001740  0.056386  0.206021     0.996723
# released     1.000000  0.045874  0.028833    -0.005141
# score        0.045874  1.000000  0.474256     0.062648
# votes        0.028833  0.474256  1.000000     0.204183
# yearcorrect -0.005141  0.062648  0.204183     1.000000

# %%
pd.set_option('display.max_rows', 100)

# %%
correlation_mat = df_categorized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              genre          0.010996
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#                               ...
# yearcorrect  year           0.996723
#              released      -0.005141
#              score          0.062648
#              votes          0.204183
#              yearcorrect    1.000000
# Length: 256, dtype: float64
